# %% [markdown]
# <a href="https://colab.research.google.com/github/polaganirashmitha627-source/streamli2/blob/main/SVC_alorgithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from  sklearn.svm import SVC

X = np.array([[1], [2], [3], [4], [5]])
y = np.array([0, 0, 1, 1, 1])

model=SVC(kernel='linear')

model.fit(X, y)

print(model.predict([[2.5]]))
# Out:
# [1]

# %%
from sklearn.tree import DecisionTreeClassifier

X = [[1], [2], [3], [4], [5]]
y = [0, 0, 1, 1, 1]

model = DecisionTreeClassifier()
model.fit(X, y)

print("Prediction:", model.predict([[2]]))
# Out:
# Prediction: [0]

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier

X = np.array([[1], [2], [3], [4], [5]])
y = np.array([0, 0, 1, 1, 1])

model = RandomForestClassifier(n_estimators=3)

model.fit(X, y)

print(model.predict([[2.5]]))
# Out:
# [0]

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

X = np.array([[1], [2], [3], [4], [5]])
y = np.array([40, 50, 60, 70, 80])

model = LinearRegression()
model.fit(X, y)

print(model.predict([[6]]))
# Out:
# [90.]
